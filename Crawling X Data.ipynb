# %%
# harus punya twitter token!
# ambil token : inspect (f12) -> Application -> Storage -> Cookies (https://twitter.com) -> authtoken -> coppy Cookie Value
twitter_auth_token = '7de841b1e7d7609ead7676d5cb09dc211187d415'

# %%
# buat proses crawling kita pakai twittter Harvest, ambil pandas dan node.js
# !pip install pandas

# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ...

# %%
# Proses ambil crawling data dari X

filename = 'korupsi.csv'
search_keyword = 'korupsi lang:id'
limit = 200

# !npx -y tweet-harvest@2.6.0 -o "{filename}" -s "{search_keyword}" -l {limit} --token "{twitter_auth_token}"
# Out:
# Tweet Harvest [v2.6.0]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Filling in keywords: korupsi lang:id
#
#
# -- Scrolling... (1)Created new directory: /content/tweets-data
#
#
# Your tweets saved to: /content/tweets-data/korupsi.csv
# Total tweets saved: 20
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/korupsi.csv
# Total tweets saved: 40
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/korupsi.csv
# Total tweets saved: 60
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/korupsi.csv
# Total tweets saved: 80
#
# -- Scrolling... (1) (2) (3) (4) (5) (6) (7)
#
# ...

# %%
import pandas as pd
path = f"tweets-data/{filename}"
dataku = pd.read_csv(path, delimiter=",")

# dataku.head()
display(dataku)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1789869083426488435  Mon May 13 04:03:38 +0000 2024             144
# 1    1789577403754578152  Sun May 12 08:44:36 +0000 2024             408
# 2    1789836033380499644  Mon May 13 01:52:18 +0000 2024             905
# 3    1787103846223024486  Sun May 05 12:55:34 +0000 2024            1144
# 4    1789903553739272344  Mon May 13 06:20:36 +0000 2024              18
# ..                   ...                             ...             ...
# 200  1789682572831908345  Mon May 13 03:35:24 +0000 2024               0
# 201  1789901673076289714  Mon May 13 06:13:08 +0000 2024               3
# 202  1788166117414068588  Wed May 08 11:16:39 +0000 2024              82
# 203  1788359579862249629  Thu May 09 00:05:24 +0000 2024              54
# 204  1788552985553039546  Thu May 09 12:53:56 +0000 2024             186
#
#                                              full_text               id_str  \
# ...

# %% [markdown]
# **Tidak semua kolom perlu diambil untuk pendekatan NLP, cukup ambil kolom full text!**
